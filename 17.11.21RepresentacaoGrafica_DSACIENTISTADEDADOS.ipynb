# %% [markdown]
# # <font color='blue'>Data Science Academy</font>
# # <font color='blue'>Big Data Real-Time Analytics com Python e Spark</font>
#
# # <font color='blue'>Capítulo 3 Exercício Guiado Realizado 17/11/2021</font>

# %% [markdown]
# ## Gráficos Estatísticos com Seaborn
# https://seaborn.pydata.org/
#
#
# http://seaborn.pydata.org/examples/index.html

# %%
#Instalando
# !pip install seaborn

# %%
#Instalando Pscotes
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
sns.__version__
# Out:
# '0.11.2'

# %%
# Datasets importados junto com o Seaborn---> Ex de datasets
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# Carregando um dataset IRIS
iris = sns.load_dataset("iris")

# %%
#TIPO
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
#PRIMEIRAS 5 LINHAS
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#Resumo estatistico
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# ## Construindo Gráficos Estatísticos

# %%
# Histograma com estimativa de densidade de kernel - Distribuição univariada
#Plot de distribuicao univariada variavel sepal_length dataset iris
sns.distplot(iris.sepal_length, rug = True, fit = stats.gausshyper);

# %%
# Scatterplot - Distribuição bivariada
#Variavel em X e Y e o Dataset
#O Histograma 
sns.jointplot(x = "sepal_length", y = "petal_length", data = iris);

# %%
#Mesma representacao grafica acima, apenas customizando
# Gráfico útil quando estiver trabalhando com grandes conjuntos de dados - Distribuição bivariada
with sns.axes_style("white"):
    sns.jointplot(x = "sepal_length", y = "petal_length", data = iris, kind = "hex", color  ="k");

# %%
#Customizando
# Distribuição bivariada
sns.jointplot(x = "sepal_length", y = "petal_length", data = iris, kind = "kde");

# %%
#Customizando
# Distribuição bivariada
g = sns.jointplot(x = "sepal_length", y = "petal_length", data = iris, kind = "kde", color = "m")
g.plot_joint(plt.scatter, c = "w", s = 30, linewidth = 1, marker = "+")
g.ax_joint.collections[0].set_alpha(0);

# %%
#Combinação gráfica
# Plot para distirbuições bi-variadas
sns.pairplot(iris);

# %% [markdown]
# ## Visualização de Relacionamento Linear

# %%
# Carregando o dataset tips - outro conjunto de dados
tips = sns.load_dataset("tips")

# %%
#Tipo
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
#Visualizando linhas 
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Resumo estatistico
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#Regressao linear + HISTOGRAMA
# Scatterplot com linha de regressão - Distribuição bivariada 
sns.jointplot(x = "total_bill", y = "tip", data = tips, kind = "reg");

# %%
#MODELO LINEAR
# Regressão Linear (utiliza 95% de intervalo de confiança por padrão)
# tip - variável dependente
# total_bill - variável independente
sns.lmplot(x = "total_bill", y = "tip", data = tips);
